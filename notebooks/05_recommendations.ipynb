# %% [markdown]
# # Recommandations par segment
#
# Ce notebook reprend la synthèse produite à l'étape 04 - caractérisation des segments.

# %% [markdown]
# | Segment | Nb clients | Moyenne du CA | Indice de valeur | Panier moyen (£) | Récence moy. (j) | Action recommandée |
# |---:|---:|---:|---:|---:|---:|---|
# | 0 | 1186 | 10641.6 | 73.9 | 10641.6 | 28.0 | Fidéliser en priorité : programme VIP, avant-premières, remerciement personnalisé |
# | 1 | 1452 | 1919.7 | 16.3 | 1919.7 | 227.7 | Contact prioritaire : ces clients avaient de la valeur, à ne pas perdre |
# | 3 | 1246 | 841.9 | 6.1 | 841.9 | 28.2 | Encourager le 2e achat : onboarding, offre de bienvenue ciblée |
# | 2 | 1969 | 317.2 | 3.7 | 317.2 | 392.6 | Campagne de réactivation urgente : offre de retour, email de relance |
#
# ## Priorités d'action
#
# 1. **Segment 0 - clients à forte valeur :** renforcer la fidélisation et la reconnaissance.
# 2. **Segment 1 - clients à risque :** reprendre rapidement contact pour éviter leur perte.
# 3. **Segment 3 - clients prometteurs :** convertir le premier achat en relation durable.
# 4. **Segment 2 - clients inactifs :** lancer une campagne de réactivation mesurable.
